# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/transformed/Transformed_data.csv")

# %%
dfg = pd.get_dummies(data = df, columns = ["Location","Type"],dtype=int)

# %%
df.describe()
# Out:
#                Area        BHK     Price_num    Price/Sqft
# count    806.000000  806.00000  8.060000e+02  8.060000e+02
# mean    1694.176799    2.39206  7.000065e+08  2.024085e+05
# std     1488.057571    0.87768  1.367892e+10  2.291131e+06
# min      450.000000    0.00000  4.000000e+05  9.200000e+01
# 25%     1100.000000    2.00000  4.500000e+06  3.750000e+03
# 50%     1380.000000    2.00000  6.500000e+06  5.000000e+03
# 75%     1798.500000    3.00000  9.500000e+06  6.293750e+03
# max    30490.000000    6.00000  3.822059e+11  5.529599e+07

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Area'}>,
#         <Axes: title={'center': 'BHK'}>],
#        [<Axes: title={'center': 'Price_num'}>,
#         <Axes: title={'center': 'Price/Sqft'}>]], dtype=object)

# %%
len(df[df["Area"] < 1500])
# Out:
# 460

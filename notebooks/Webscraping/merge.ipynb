# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df1 = pd.read_csv("data1.csv")

# %%
df3 = pd.concat([df,df1],ignore_index=True)

# %%
df3.to_csv("data.csv")

# %%
df3
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  \
# 0             0.0           0.0
# 1             1.0           1.0
# 2             2.0           2.0
# 3             3.0           3.0
# 4             4.0           4.0
# ..            ...           ...
# 953           NaN           NaN
# 954           NaN           NaN
# 955           NaN           NaN
# 956           NaN           NaN
# 957           NaN           NaN
#
#                                                  Title       Price       Area  \
# 0              3 BHK Flat for Sale in Bejai, Mangalore     ₹65 Lac  1505 sqft
# 1        2 BHK Flat for Sale in Krishnapura, Mangalore     ₹44 Lac  1100 sqft
# 2          2 BHK Flat for Sale in Surathkal, Mangalore     ₹45 Lac  1203 sqft
# 3        3 BHK Flat for Sale in Hampankatta, Mangalore     ₹98 Lac  1402 sqft
# 4             2 BHK Flat for Sale in Kavoor, Mangalore     ₹35 Lac  1185 sqft
# ..                                                 ...         ...        ...
# ...

# %%
df
# Out:
#                                                   Title       Price  \
# 0               3 BHK Flat for Sale in Bejai, Mangalore     ₹65 Lac
# 1         2 BHK Flat for Sale in Krishnapura, Mangalore     ₹44 Lac
# 2           2 BHK Flat for Sale in Surathkal, Mangalore     ₹45 Lac
# 3         3 BHK Flat for Sale in Hampankatta, Mangalore     ₹98 Lac
# 4              2 BHK Flat for Sale in Kavoor, Mangalore     ₹35 Lac
# ...                                                 ...         ...
# 1016  1 BHK 659 Sqft Apartment for Sale in Kadri, Ma...  34.46 Lakh
# 1017  3 BHK 1608 Sqft Apartment for Sale in Konchady...  84.07 Lakh
# 1018  1 BHK 659 Sqft Apartment for Sale in Konchady,...  34.46 Lakh
# 1019  2 BHK 1254 Sqft Apartment for Sale in Konchady...  65.56 Lakh
# 1020  2 BHK 1285 Sqft Apartment for Sale in Konchady...  67.18 Lakh
#
#            Area    Area-Type
# 0     1505 sqft  Carpet Area
# 1     1100 sqft   Super Area
# 2     1203 sqft   Super Area
# 3     1402 sqft   Super Area
# ...

# %%
df1
# Out:
#     Unnamed: 0                                              Title       Price  \
# 0            0     3 BHK Apartment for Sale in Kottara, Mangalore    72 Lakhs
# 1            1       3 BHK Apartment for Sale in Kulai, Mangalore    80 Lakhs
# 2            2  2 BHK 1040 Sqft Apartment for Sale in Yeyyadi,...  43.68 Lakh
# 3            3  2 BHK 1091 Sqft Apartment for Sale in Derebail...  50.69 Lakh
# 4            4    3 BHK Apartment for Sale in Derebail, Mangalore    60 Lakhs
# 5            5  4+ BHK 6500 Sqft Apartment for Sale in Shivaba...  4.87 Crore
# 6            6  1 BHK 659 Sqft Apartment for Sale in Kodiabail...  34.46 Lakh
# 7            7  2 BHK 1109 Sqft Apartment for Sale in Jeppinam...  57.98 Lakh
# 8            8  2 BHK 1225 Sqft Apartment for Sale in Karangal...  64.05 Lakh
# 9            9  3 BHK 1665 Sqft Villa for Sale in Karangalpady...  87.05 Lakh
# 10          10  3 BHK 1608 Sqft Apartment for Sale in Karangal...  84.07 Lakh
# ...

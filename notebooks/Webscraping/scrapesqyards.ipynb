# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.quikr.com/homes/property/residential-for-sale-in-mangalore-cid_575001?page=29"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36"}

# %%
res = requests.get(url, headers = headers)

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
df = {"Title": [], "Price": [], "Area":[] ,"Area-Type": []}

# %%
df
# Out:
# {'Title': [], 'Price': [], 'Area': [], 'Area-Type': []}

# %%
for name in soup.find_all("a", class_ = "listtitle notclickb"):
    title = name.text.strip()
    df["Title"].append(title)

# %%
for pric in soup.find_all("div",class_ ="prsg"):
    price = pric.find("span").text.strip()
    df["Price"].append(price)

# %%
soup.find_all("ul", class_ = "project_d clearfix")[0].find_all("span")[1].text.split()[0]+" sqft"
# Out:
# '1020 sqft'

# %%
for ar in soup.find_all("ul", class_ = "project_d clearfix"):
    area = ar.find_all("span")[1].text.split()[0]+" sqft"
    df["Area"].append(area)
    df["Area-Type"].append("Super Area")

# %%
df
# Out:
# {'Title': ['2 BHK Apartment for Sale in Kulai, Mangalore',
#   '3 BHK 1691 Sqft Apartment for Sale in Derebail, Mangalore',
#   '3 BHK Apartment for Sale in Derebail, Mangalore',
#   '3 BHK Villa for Sale in Puttur, Mangalore',
#   '2 BHK Apartment for Sale in Bondel, Mangalore',
#   '4+ BHK Apartment for Sale in Shivabaugh, Mangalore',
#   '3 BHK Apartment for Sale in Attavar, Mangalore',
#   '3 BHK Apartment for Sale in Attavar, Mangalore',
#   '5200 Sq. ft Plot for Sale in Derlakatte, Mangalore',
#   '3 BHK Apartment for Sale in Padil, Mangalore',
#   '3 BHK 2315 Sq.ft, Apartment for Sale in Kodailbail, Mangalore.',
#   '3 BHK 1915 Sq.ft, Apartment for Sale in Kodailbail, Mangalore.',
#   '1 BHK 634 Sq.ft, Apartment for Sale in Surathkal, Mangalore.',
#   '1 BHK 645 Sq.ft, Apartment for Sale in Surathkal, Mangalore.',
#   '2 BHK 915 Sq.ft, Apartment for Sale in Surathkal, Mangalore.',
#   '2 BHK 1170 Sq.ft, Apartment for Sale in Surathkal, Mangalore.',
# ...

# %%
dfr = pd.DataFrame(df)

# %%
dfr.to_csv("data1.csv")

# %%
dfr
# Out:
#                                                 Title       Price       Area  \
# 0       2 BHK Apartment for Sale in Bondel, Mangalore  71.50 Lakh  1265 sqft
# 1   3 BHK 1265 Sq.ft, Villa for Sale in Vas Lane, ...    89 Lakhs  1265 sqft
# 2        3 BHK Apartment for Rent in Kadri, Mangalore      16,000  1600 sqft
# 3   2 BHK 1200 Sqft Apartment for Sale in Mannagud...  69.40 Lakh  1200 sqft
# 4     3 BHK Apartment for Sale in Derebail, Mangalore    68 Lakhs  1360 sqft
# 5   2 BHK Apartment for Sale in Mannagudda, Mangalore  71.39 Lakh  1165 sqft
# 6   3 BHK 1691 Sqft Apartment for Sale in Kodiabai...  88.41 Lakh  1691 sqft
# 7   3 BHK 1380 Sqft Apartment for Sale in Kavoor, ...  72.15 Lakh  1380 sqft
# 8   3 BHK 1490 Sqft Apartment for Sale in Karangal...  77.90 Lakh  1490 sqft
# 9   3 BHK 1691 Sqft Apartment for Sale in Karangal...  88.41 Lakh  1691 sqft
# 10  2 BHK 1109 Sqft Apartment for Sale in Kankanad...  57.98 Lakh  1109 sqft
# ...
